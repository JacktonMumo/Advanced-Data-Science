# %%
import pandas

#collect our dataset
data = pandas.read_csv("school.csv", parse_dates= ['bday', 'enrolldate','expgradate'])
data
# Out:
#        ids       bday enrolldate expgradate  Rank                    Major  \
# 0    43783 1995-03-22        NaT        NaT   NaN                      NaN
# 1    20278 1995-01-01        NaT        NaT   NaN               Philosophy
# 2    20389 1994-12-31        NaT        NaT   NaN                      NaN
# 3    22820 1994-12-01        NaT        NaT   NaN  business administration
# 4    24559 1994-11-10        NaT        NaT   NaN                      NaN
# ..     ...        ...        ...        ...   ...                      ...
# 430  34021 1987-07-18 2011-08-01 2017-05-08   4.0               accounting
# 431  40697 1987-04-29 2011-08-01 2016-05-09   4.0                      NaN
# 432  34272        NaT 2011-08-01 2016-05-09   4.0                  nursing
# 433  33628        NaT 2011-08-01 2017-05-08   4.0                  Nursing
# 434  39298        NaT 2011-08-01 2017-05-08   4.0                      NaN
#
#      Gender  Athlete  Height  Weight  ...  English  Reading   Math  Writing  \
# 0       0.0        0   72.35     NaN  ...    88.24    81.50  60.02    81.44
# 1       0.0        0   70.66  179.20  ...    89.45    85.25  70.19    73.27
# 2       0.0        0   70.68  198.52  ...    96.73    86.88  71.20    84.24
# 3       1.0        0     NaN  198.34  ...    74.06    88.68  55.89    73.16
# 4       1.0        1   67.43  128.17  ...    82.61    77.30  65.52    80.45
# ..      ...      ...     ...     ...  ...      ...      ...    ...      ...
# 430     1.0        0     NaN     NaN  ...    87.72    84.99  65.31      NaN
# 431     0.0        0   68.50  131.92  ...    91.01    86.87  70.25    82.67
# 432     0.0        1   68.10  130.07  ...    81.05    85.76  58.16    81.87
# 433     1.0        1   69.27  157.26  ...    75.59    85.97  66.84    79.35
# 434     1.0        1   66.68  152.33  ...    75.65    77.24  60.24    75.23
#
#             State  LiveOnCampus  HowCommute CommuteTime  SleepTime  StudyTime
# 0        In state           1.0         NaN         NaN        7.0        1.0
# 1             NaN           1.0         NaN         NaN        5.0        2.0
# 2        In state           NaN         NaN         NaN        8.0        7.0
# 3        In state           1.0         NaN         NaN        2.0        6.0
# 4    Out of state           1.0         NaN         NaN        7.0        3.0
# ..            ...           ...         ...         ...        ...        ...
# 430      In state           0.0         1.0        18.0        1.0       10.0
# 431      In state           0.0         3.0        26.0        6.0       15.0
# 432           NaN           0.0         3.0        29.0        6.0       10.0
# 433      In state           0.0         1.0        14.0        4.0       10.0
# 434      In state           0.0         3.0        27.0        2.0       10.0
#
# [435 rows x 23 columns]

# %%
data.head(10) #viewing the first 10 rows
# Out:
#      ids       bday enrolldate expgradate  Rank                    Major  \
# 0  43783 1995-03-22        NaT        NaT   NaN                      NaN
# 1  20278 1995-01-01        NaT        NaT   NaN               Philosophy
# 2  20389 1994-12-31        NaT        NaT   NaN                      NaN
# 3  22820 1994-12-01        NaT        NaT   NaN  business administration
# 4  24559 1994-11-10        NaT        NaT   NaN                      NaN
# 5  28980 1994-09-17        NaT        NaT   NaN             astrophysics
# 6  33312 1994-07-27        NaT        NaT   NaN             Anthropology
# 7  40274 1994-05-03        NaT        NaT   NaN         American History
# 8  40390 1994-04-30        NaT        NaT   NaN         Africana studies
# 9  28942 1993-09-17        NaT        NaT   NaN                      NaN
#
#    Gender  Athlete  Height  Weight  ...  English  Reading   Math  Writing  \
# 0     0.0        0   72.35     NaN  ...    88.24    81.50  60.02    81.44
# 1     0.0        0   70.66  179.20  ...    89.45    85.25  70.19    73.27
# 2     0.0        0   70.68  198.52  ...    96.73    86.88  71.20    84.24
# 3     1.0        0     NaN  198.34  ...    74.06    88.68  55.89    73.16
# 4     1.0        1   67.43  128.17  ...    82.61    77.30  65.52    80.45
# 5     0.0        1   68.45  171.61  ...    70.10      NaN  61.40    77.48
# 6     0.0        1   68.56  163.96  ...    78.98    87.53  76.71    70.79
# 7     0.0        1   71.91  222.87  ...      NaN    67.31  58.64    65.89
# 8     1.0        1   68.84  154.70  ...    75.65    76.54  51.14    75.94
# 9     1.0        1   66.69  180.57  ...    68.27    93.88  55.20    78.18
#
#           State  LiveOnCampus  HowCommute CommuteTime  SleepTime  StudyTime
# 0      In state           1.0         NaN         NaN        7.0        1.0
# 1           NaN           1.0         NaN         NaN        5.0        2.0
# 2      In state           NaN         NaN         NaN        8.0        7.0
# 3      In state           1.0         NaN         NaN        2.0        6.0
# 4  Out of state           1.0         NaN         NaN        7.0        3.0
# 5      In state           1.0         NaN         NaN        8.0        3.0
# 6      In state           1.0         NaN         NaN        9.0        9.0
# 7      In state           0.0         NaN         NaN        8.0        3.0
# 8      In state           0.0         3.0        26.0        NaN        3.0
# 9  Out of state           NaN         1.0        13.0        2.0       15.0
#
# [10 rows x 23 columns]

# %%
# number of rows and columns
data.shape
# Out:
# (435, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ids           435 non-null    int64
#  1   bday          427 non-null    datetime64[ns]
#  2   enrolldate    406 non-null    datetime64[ns]
#  3   expgradate    406 non-null    datetime64[ns]
#  4   Rank          406 non-null    float64
#  5   Major         276 non-null    object
#  6   Gender        426 non-null    float64
#  7   Athlete       435 non-null    int64
#  8   Height        408 non-null    float64
#  9   Weight        376 non-null    float64
#  10  Smoking       411 non-null    float64
#  11  Sprint        374 non-null    float64
#  12  MileMinDur    392 non-null    object
#  13  English       409 non-null    float64
#  14  Reading       425 non-null    float64
#  15  Math          422 non-null    float64
#  16  Writing       404 non-null    float64
#  17  State         408 non-null    object
#  18  LiveOnCampus  414 non-null    float64
#  19  HowCommute    247 non-null    float64
#  20  CommuteTime   247 non-null    float64
#  21  SleepTime     403 non-null    float64
#  22  StudyTime     393 non-null    float64
# dtypes: datetime64[ns](3), float64(15), int64(2), object(3)
# memory usage: 78.3+ KB

# %%
data['Gender']
# Out:
# 0      0.0
# 1      0.0
# 2      0.0
# 3      1.0
# 4      1.0
#       ...
# 430    1.0
# 431    0.0
# 432    0.0
# 433    1.0
# 434    1.0
# Name: Gender, Length: 435, dtype: float64

# %%
data[['Gender','ids']].head(2)
# Out:
#    Gender    ids
# 0     0.0  43783
# 1     0.0  20278

# %%
data.sort_values('English', ascending= True).head(5)
# Out:
#        ids       bday enrolldate expgradate  Rank      Major  Gender  Athlete  \
# 104  34919 1994-07-07 2014-08-04 2020-05-11   1.0   biologie     0.0        0
# 67   42850 1995-04-02 2014-08-04 2019-05-13   1.0  Higher Ed     0.0        0
# 133  26481 1993-10-18 2014-08-04 2019-05-13   1.0        NaN     0.0        1
# 164  34176 1992-07-17 2014-08-04 2019-05-13   1.0         CS     0.0        1
# 146  38091 1993-05-29 2014-08-04 2019-05-13   1.0        NaN     0.0        1
#
#      Height  Weight  ...  English  Reading   Math  Writing         State  \
# 104   73.35     NaN  ...    59.83    74.71  55.54    74.97      In state
# 67    62.84  115.98  ...    60.96    69.87  58.97    71.56      In state
# 133   73.36  181.20  ...    64.01    76.44  68.95    73.62  Out of state
# 164   69.70  173.56  ...    65.26    77.09  56.32    72.51  Out of state
# 146   78.68  238.64  ...    67.03    68.43  64.06    68.87      In state
#
#      LiveOnCampus  HowCommute CommuteTime  SleepTime  StudyTime
# 104           1.0         NaN         NaN        6.0        7.0
# 67            1.0         NaN         NaN        1.0        4.0
# 133           1.0         NaN         NaN        4.0       11.0
# 164           1.0         NaN         NaN        4.0        5.0
# 146           1.0         NaN         NaN        5.0        8.0
#
# [5 rows x 23 columns]

# %%
# cleaning quantitative data types/columns
data.isnull().sum() # if cell is empty it will print true, if not empty it will print false
# Out:
# ids               0
# bday              8
# enrolldate       29
# expgradate       29
# Rank             29
# Major           159
# Gender            9
# Athlete           0
# Height           27
# Weight           59
# Smoking          24
# Sprint           61
# MileMinDur       43
# English          26
# Reading          10
# Math             13
# Writing          31
# State            27
# LiveOnCampus     21
# HowCommute      188
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64

# %%
#fillna()   it fills empty cells with a given value
data['Rank'].fillna(0.0, inplace=True)
data['Gender'].fillna(2.0, inplace=True)
data['Major'].fillna('unknown', inplace=True)
data['Smoking'].fillna(3.0, inplace=True)
data['State'].fillna('unknown', inplace=True)
data['LiveOnCampus'].fillna( 2.0, inplace=True)
data['HowCommute'].fillna(4.0 , inplace=True)
data.isnull().sum()
# Out:
# /tmp/ipykernel_2256/4115318981.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Rank'].fillna(0.0, inplace=True)
# /tmp/ipykernel_2256/4115318981.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Major'].fillna('unknown', inplace=True)
# /tmp/ipykernel_2256/4115318981.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Smoking'].fillna(3.0, inplace=True)
# /tmp/ipykernel_2256/4115318981.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['State'].fillna('unknown', inplace=True)
# /tmp/ipykernel_2256/4115318981.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LiveOnCampus'].fillna( 2.0, inplace=True)
# /tmp/ipykernel_2256/4115318981.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['HowCommute'].fillna(4.0 , inplace=True)
# ids               0
# bday              8
# enrolldate       29
# expgradate       29
# Rank              0
# Major             0
# Gender            0
# Athlete           0
# Height           27
# Weight           59
# Smoking           0
# Sprint           61
# MileMinDur       43
# English          26
# Reading          10
# Math             13
# Writing          31
# State             0
# LiveOnCampus      0
# HowCommute        0
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64

# %%
# replacing cells with different values, replace()
data['Gender'].replace({
    0:'Male',
    1:'Female',
    2:'Neutral'
},inplace=True)
data['LiveOnCampus'].replace({
    0:'Off Campus',
    1:'On Campus',
    2:'unknown'
},inplace=True)
data['HowCommute'].replace({
    1:'Walk',
    2:'Bike',
    3:'Car',
    4:'Public Transit'
},inplace=True)
data['Rank'].replace({
    0:'Unknown',
    1:'First position',
    2:'First runners up',
    3:'Second runners up',
    4:'Fourth position'
},inplace=True)
data['Smoking'].replace({
    0:'Not a smoker',
    1:'Smoker',
    2:'Unknown'
},inplace=True)
data.head(10)
# Out:
# /tmp/ipykernel_2256/3943516556.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LiveOnCampus'].replace({
# /tmp/ipykernel_2256/3943516556.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['HowCommute'].replace({
# /tmp/ipykernel_2256/3943516556.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Rank'].replace({
# /tmp/ipykernel_2256/3943516556.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Smoking'].replace({
#      ids       bday enrolldate expgradate     Rank                    Major  \
# 0  43783 1995-03-22        NaT        NaT  Unknown                  unknown
# 1  20278 1995-01-01        NaT        NaT  Unknown               Philosophy
# 2  20389 1994-12-31        NaT        NaT  Unknown                  unknown
# 3  22820 1994-12-01        NaT        NaT  Unknown  business administration
# 4  24559 1994-11-10        NaT        NaT  Unknown                  unknown
# 5  28980 1994-09-17        NaT        NaT  Unknown             astrophysics
# 6  33312 1994-07-27        NaT        NaT  Unknown             Anthropology
# 7  40274 1994-05-03        NaT        NaT  Unknown         American History
# 8  40390 1994-04-30        NaT        NaT  Unknown         Africana studies
# 9  28942 1993-09-17        NaT        NaT  Unknown                  unknown
#
#    Gender  Athlete  Height  Weight  ... English  Reading   Math  Writing  \
# 0    Male        0   72.35     NaN  ...   88.24    81.50  60.02    81.44
# 1    Male        0   70.66  179.20  ...   89.45    85.25  70.19    73.27
# 2    Male        0   70.68  198.52  ...   96.73    86.88  71.20    84.24
# 3  Female        0     NaN  198.34  ...   74.06    88.68  55.89    73.16
# 4  Female        1   67.43  128.17  ...   82.61    77.30  65.52    80.45
# 5    Male        1   68.45  171.61  ...   70.10      NaN  61.40    77.48
# 6    Male        1   68.56  163.96  ...   78.98    87.53  76.71    70.79
# 7    Male        1   71.91  222.87  ...     NaN    67.31  58.64    65.89
# 8  Female        1   68.84  154.70  ...   75.65    76.54  51.14    75.94
# 9  Female        1   66.69  180.57  ...   68.27    93.88  55.20    78.18
#
#           State  LiveOnCampus      HowCommute CommuteTime SleepTime StudyTime
# 0      In state     On Campus  Public Transit         NaN       7.0       1.0
# 1       unknown     On Campus  Public Transit         NaN       5.0       2.0
# 2      In state       unknown  Public Transit         NaN       8.0       7.0
# 3      In state     On Campus  Public Transit         NaN       2.0       6.0
# 4  Out of state     On Campus  Public Transit         NaN       7.0       3.0
# 5      In state     On Campus  Public Transit         NaN       8.0       3.0
# 6      In state     On Campus  Public Transit         NaN       9.0       9.0
# 7      In state    Off Campus  Public Transit         NaN       8.0       3.0
# 8      In state    Off Campus             Car        26.0       NaN       3.0
# 9  Out of state       unknown            Walk        13.0       2.0      15.0
#
# [10 rows x 23 columns]

# %%
#dropping columns
# in pandas column/vertical is axis-1, and row/horizontal is axis-0
data.drop(['MileMinDur'],axis=1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ids           435 non-null    int64
#  1   bday          427 non-null    datetime64[ns]
#  2   enrolldate    406 non-null    datetime64[ns]
#  3   expgradate    406 non-null    datetime64[ns]
#  4   Rank          435 non-null    object
#  5   Major         435 non-null    object
#  6   Gender        435 non-null    object
#  7   Athlete       435 non-null    int64
#  8   Height        408 non-null    float64
#  9   Weight        376 non-null    float64
#  10  Smoking       435 non-null    object
#  11  Sprint        374 non-null    float64
#  12  English       409 non-null    float64
#  13  Reading       425 non-null    float64
#  14  Math          422 non-null    float64
#  15  Writing       404 non-null    float64
#  16  State         435 non-null    object
#  17  LiveOnCampus  435 non-null    object
#  18  HowCommute    435 non-null    object
#  19  CommuteTime   247 non-null    float64
#  20  SleepTime     403 non-null    float64
#  21  StudyTime     393 non-null    float64
# dtypes: datetime64[ns](3), float64(10), int64(2), object(7)
# memory usage: 74.9+ KB

# %%
#drop rows(duplicates)
data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ids           435 non-null    int64
#  1   bday          427 non-null    datetime64[ns]
#  2   enrolldate    406 non-null    datetime64[ns]
#  3   expgradate    406 non-null    datetime64[ns]
#  4   Rank          435 non-null    object
#  5   Major         435 non-null    object
#  6   Gender        435 non-null    object
#  7   Athlete       435 non-null    int64
#  8   Height        408 non-null    float64
#  9   Weight        376 non-null    float64
#  10  Smoking       435 non-null    object
#  11  Sprint        374 non-null    float64
#  12  English       409 non-null    float64
#  13  Reading       425 non-null    float64
#  14  Math          422 non-null    float64
#  15  Writing       404 non-null    float64
#  16  State         435 non-null    object
#  17  LiveOnCampus  435 non-null    object
#  18  HowCommute    435 non-null    object
#  19  CommuteTime   247 non-null    float64
#  20  SleepTime     403 non-null    float64
#  21  StudyTime     393 non-null    float64
# dtypes: datetime64[ns](3), float64(10), int64(2), object(7)
# memory usage: 74.9+ KB

# %%
#drop rows on specifications
new_data =data[data['Gender'] != 'Male']
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 231 entries, 3 to 434
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ids           231 non-null    int64
#  1   bday          228 non-null    datetime64[ns]
#  2   enrolldate    218 non-null    datetime64[ns]
#  3   expgradate    218 non-null    datetime64[ns]
#  4   Rank          231 non-null    object
#  5   Major         231 non-null    object
#  6   Gender        231 non-null    object
#  7   Athlete       231 non-null    int64
#  8   Height        219 non-null    float64
#  9   Weight        201 non-null    float64
#  10  Smoking       231 non-null    object
#  11  Sprint        198 non-null    float64
#  12  English       221 non-null    float64
#  13  Reading       228 non-null    float64
#  14  Math          224 non-null    float64
#  15  Writing       213 non-null    float64
#  16  State         231 non-null    object
#  17  LiveOnCampus  231 non-null    object
#  18  HowCommute    231 non-null    object
#  19  CommuteTime   129 non-null    float64
#  20  SleepTime     209 non-null    float64
#  21  StudyTime     208 non-null    float64
# dtypes: datetime64[ns](3), float64(10), int64(2), object(7)
# memory usage: 41.5+ KB

# %%
new_data = data[data['ids'] !=49688]

# %%
#summarize quantitative datatypes or columns. describe()
data.describe()
# Out:
#                 ids                           bday  \
# count    435.000000                            427
# mean   35279.022989  1993-01-14 10:27:15.597189632
# min    20183.000000            1985-09-03 00:00:00
# 25%    28001.000000            1991-09-28 12:00:00
# 50%    35350.000000            1993-05-25 00:00:00
# 75%    42655.500000            1994-07-12 00:00:00
# max    49947.000000            1996-01-02 00:00:00
# std     8637.733605                            NaN
#
#                           enrolldate                     expgradate  \
# count                            406                            406
# mean   2013-05-23 06:12:24.827586304  2018-09-08 06:37:14.482758656
# min              2011-08-01 00:00:00            2016-05-09 00:00:00
# 25%              2012-08-06 00:00:00            2017-05-08 00:00:00
# 50%              2013-08-05 00:00:00            2018-05-14 00:00:00
# 75%              2014-08-04 00:00:00            2019-05-13 00:00:00
# max              2014-08-04 00:00:00            2020-05-11 00:00:00
# std                              NaN                            NaN
#
#           Athlete      Height      Weight      Sprint     English     Reading  \
# count  435.000000  408.000000  376.000000  374.000000  409.000000  425.000000
# mean     0.422989   68.031765  181.031569    6.581933   82.787555   82.070800
# min      0.000000   55.000000  101.710000    4.503000   59.830000   55.110000
# 25%      0.000000   64.827500  153.860000    5.587500   78.330000   77.190000
# 50%      0.000000   67.570000  172.960000    6.569000   83.150000   81.940000
# 75%      1.000000   71.575000  204.307500    7.458000   87.170000   87.080000
# max      1.000000   84.410000  350.070000    9.597000  101.950000  103.620000
# std      0.494602    5.325655   42.749680    1.227069    6.839803    7.661778
#
#              Math     Writing  CommuteTime   SleepTime   StudyTime
# count  422.000000  404.000000   247.000000  403.000000  393.000000
# mean    65.468009   79.521683    27.000000    5.461538    7.208651
# min     35.320000   64.060000     4.000000    0.000000    0.000000
# 25%     60.202500   75.750000    21.000000    4.000000    4.000000
# 50%     65.445000   79.035000    27.000000    5.000000    6.000000
# 75%     70.567500   83.687500    32.000000    7.000000   10.000000
# max     93.780000   93.010000    64.000000   13.000000   23.000000
# std      8.375930    5.511410    10.072905    2.421994    4.356233

# %%
# removing date null cells using Timestamp
data['bday'] = data['bday'].fillna(pandas.Timestamp('2000-01-01'))
data['enrolldate'] = data['enrolldate'].fillna(pandas.Timestamp('2000-01-01'))
data['expgradate'] = data['expgradate'].fillna(pandas.Timestamp('2000-01-01'))

data.isnull().sum()
# Out:
# ids               0
# bday              0
# enrolldate        0
# expgradate        0
# Rank              0
# Major             0
# Gender            0
# Athlete           0
# Height           27
# Weight           59
# Smoking           0
# Sprint           61
# English          26
# Reading          10
# Math             13
# Writing          31
# State             0
# LiveOnCampus      0
# HowCommute        0
# CommuteTime     188
# SleepTime        32
# StudyTime        42
# dtype: int64

# %%
# Find Weight mean
mean_weight = data['Weight'].mean()
mean_height = data['Height'].mean()
mean_sprint = data['Sprint'].mean()
mean_english = data['English'].mean()
mean_reading = data['Reading'].mean()
mean_math = data['Math'].mean()
mean_writing = data['Writing'].mean()
mean_commutetime = data['CommuteTime'].mean()
mean_sleeptime = data['SleepTime'].mean()
mean_studytime = data['StudyTime'].mean()



#fill the empty cells with th
data['Weight'].fillna(mean_weight, inplace=True)
data['Height'].fillna(mean_height, inplace=True)
data['Sprint'].fillna(mean_sprint, inplace=True)
data['English'].fillna(mean_english, inplace=True)
data['Reading'].fillna(mean_reading, inplace=True)
data['Math'].fillna(mean_math, inplace=True)
data['Writing'].fillna(mean_writing, inplace=True)
data['CommuteTime'].fillna(mean_commutetime, inplace=True)
data['StudyTime'].fillna(mean_studytime, inplace=True)
data['SleepTime'].fillna(mean_sleeptime, inplace=True)

data.isnull().sum()
# Out:
# /tmp/ipykernel_2256/1271696974.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Weight'].fillna(mean_weight, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Height'].fillna(mean_height, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Sprint'].fillna(mean_sprint, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['English'].fillna(mean_english, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Reading'].fillna(mean_reading, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Math'].fillna(mean_math, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Writing'].fillna(mean_writing, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['CommuteTime'].fillna(mean_commutetime, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['StudyTime'].fillna(mean_studytime, inplace=True)
# /tmp/ipykernel_2256/1271696974.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['SleepTime'].fillna(mean_sleeptime, inplace=True)
# ids             0
# bday            0
# enrolldate      0
# expgradate      0
# Rank            0
# Major           0
# Gender          0
# Athlete         0
# Height          0
# Weight          0
# Smoking         0
# Sprint          0
# English         0
# Reading         0
# Math            0
# Writing         0
# State           0
# LiveOnCampus    0
# HowCommute      0
# CommuteTime     0
# SleepTime       0
# StudyTime       0
# dtype: int64

# %%
#summariz qualitative datatypes/columns.groupby()
data.groupby('Gender').size()
# Out:
# Gender
# Female     222
# Male       204
# Neutral      9
# dtype: int64

# %%
#groupby a quantitative column
data.groupby('Math').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:12374, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6448, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6444     raise TypeError(
#    6445         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6446         "with non-numeric dtypes."
#    6447     )
# -> 6448 return op(delegate, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'First position' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 2
#       1 #groupby a quantitative column
# ----> 2 data.groupby('Math').mean()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
# groupby a math according to gender
data.groupby('Gender') ['Math'].sum()
# Out:
# Gender
# Female     14461.32
# Male       13717.97
# Neutral      618.21
# Name: Math, dtype: float64

# %%
data.groupby(['State','Gender']) [['Math','English']].sum()
# Out:
#                               Math       English
# State        Gender
# In state     Female    9786.340047  12630.087775
#              Male     10389.000047  12876.370660
#              Neutral    403.890000    492.997555
# Out of state Female    3486.076019   4487.552665
#              Male      2444.748009   3070.180220
#              Neutral    156.030000    175.460000
# unknown      Female    1017.180000   1253.137555
#              Male       737.030000    930.640000
#              Neutral     58.290000     96.160000

# %%
#creating new columns, assign()
new_data = data.assign(NewColumn='New Column cell')
new_data.head(5)
# Out:
#      ids       bday enrolldate expgradate     Rank                    Major  \
# 0  43783 1995-03-22 2000-01-01 2000-01-01  Unknown                  unknown
# 1  20278 1995-01-01 2000-01-01 2000-01-01  Unknown               Philosophy
# 2  20389 1994-12-31 2000-01-01 2000-01-01  Unknown                  unknown
# 3  22820 1994-12-01 2000-01-01 2000-01-01  Unknown  business administration
# 4  24559 1994-11-10 2000-01-01 2000-01-01  Unknown                  unknown
#
#    Gender  Athlete     Height      Weight  ... Reading   Math  Writing  \
# 0    Male        0  72.350000  181.031569  ...   81.50  60.02    81.44
# 1    Male        0  70.660000  179.200000  ...   85.25  70.19    73.27
# 2    Male        0  70.680000  198.520000  ...   86.88  71.20    84.24
# 3  Female        0  68.031765  198.340000  ...   88.68  55.89    73.16
# 4  Female        1  67.430000  128.170000  ...   77.30  65.52    80.45
#
#           State  LiveOnCampus      HowCommute CommuteTime SleepTime StudyTime  \
# 0      In state     On Campus  Public Transit        27.0       7.0       1.0
# 1       unknown     On Campus  Public Transit        27.0       5.0       2.0
# 2      In state       unknown  Public Transit        27.0       8.0       7.0
# 3      In state     On Campus  Public Transit        27.0       2.0       6.0
# 4  Out of state     On Campus  Public Transit        27.0       7.0       3.0
#
#          NewColumn
# 0  New Column cell
# 1  New Column cell
# 2  New Column cell
# 3  New Column cell
# 4  New Column cell
#
# [5 rows x 23 columns]

# %%
#lamda is a function that helps to shorten the creation of functions, thus you can create an anonymous function
#lambda x: x**2 is a function that takes a number and returns the square of that
#lambda x: x**2 is the same as def square(x)

def sum():
    return 5+10

sum = lambda x, y : x+y

# %%
data = data.assign(Score = lambda new_data: data.Reading + data.Writing + data.Math + data.English)
data.head(5)
# Out:
#      ids       bday enrolldate expgradate     Rank                    Major  \
# 0  43783 1995-03-22 2000-01-01 2000-01-01  Unknown                  unknown
# 1  20278 1995-01-01 2000-01-01 2000-01-01  Unknown               Philosophy
# 2  20389 1994-12-31 2000-01-01 2000-01-01  Unknown                  unknown
# 3  22820 1994-12-01 2000-01-01 2000-01-01  Unknown  business administration
# 4  24559 1994-11-10 2000-01-01 2000-01-01  Unknown                  unknown
#
#    Gender  Athlete     Height      Weight  ... Reading   Math  Writing  \
# 0    Male        0  72.350000  181.031569  ...   81.50  60.02    81.44
# 1    Male        0  70.660000  179.200000  ...   85.25  70.19    73.27
# 2    Male        0  70.680000  198.520000  ...   86.88  71.20    84.24
# 3  Female        0  68.031765  198.340000  ...   88.68  55.89    73.16
# 4  Female        1  67.430000  128.170000  ...   77.30  65.52    80.45
#
#           State  LiveOnCampus      HowCommute CommuteTime SleepTime StudyTime  \
# 0      In state     On Campus  Public Transit        27.0       7.0       1.0
# 1       unknown     On Campus  Public Transit        27.0       5.0       2.0
# 2      In state       unknown  Public Transit        27.0       8.0       7.0
# 3      In state     On Campus  Public Transit        27.0       2.0       6.0
# 4  Out of state     On Campus  Public Transit        27.0       7.0       3.0
#
#     Score
# 0  311.20
# 1  318.16
# 2  339.05
# 3  291.79
# 4  305.88
#
# [5 rows x 23 columns]

# %%
data = data.assign(BMI = lambda BMI : data.Weight / data.Height**2)
data.head(5)
# Out:
#      ids       bday enrolldate expgradate     Rank                    Major  \
# 0  43783 1995-03-22 2000-01-01 2000-01-01  Unknown                  unknown
# 1  20278 1995-01-01 2000-01-01 2000-01-01  Unknown               Philosophy
# 2  20389 1994-12-31 2000-01-01 2000-01-01  Unknown                  unknown
# 3  22820 1994-12-01 2000-01-01 2000-01-01  Unknown  business administration
# 4  24559 1994-11-10 2000-01-01 2000-01-01  Unknown                  unknown
#
#    Gender  Athlete     Height      Weight  ...   Math  Writing         State  \
# 0    Male        0  72.350000  181.031569  ...  60.02    81.44      In state
# 1    Male        0  70.660000  179.200000  ...  70.19    73.27       unknown
# 2    Male        0  70.680000  198.520000  ...  71.20    84.24      In state
# 3  Female        0  68.031765  198.340000  ...  55.89    73.16      In state
# 4  Female        1  67.430000  128.170000  ...  65.52    80.45  Out of state
#
#    LiveOnCampus      HowCommute  CommuteTime SleepTime StudyTime   Score  \
# 0     On Campus  Public Transit         27.0       7.0       1.0  311.20
# 1     On Campus  Public Transit         27.0       5.0       2.0  318.16
# 2       unknown  Public Transit         27.0       8.0       7.0  339.05
# 3     On Campus  Public Transit         27.0       2.0       6.0  291.79
# 4     On Campus  Public Transit         27.0       7.0       3.0  305.88
#
#         BMI
# 0  0.034584
# 1  0.035891
# 2  0.039738
# 3  0.042854
# 4  0.028189
#
# [5 rows x 24 columns]

# %%
#converting Weight Pound to KG
def convert(x):
    answer = 0.453592 * x
    return answer

data['Weight'] = data['Weight'].apply(convert)

#converting Height Inch to CM
def convert(x):
    answer = 0.0254 * x
    return answer

data['Height'] = data['Height'].apply(convert)
data.head(5)
# Out:
#      ids       bday enrolldate expgradate     Rank                    Major  \
# 0  43783 1995-03-22 2000-01-01 2000-01-01  Unknown                  unknown
# 1  20278 1995-01-01 2000-01-01 2000-01-01  Unknown               Philosophy
# 2  20389 1994-12-31 2000-01-01 2000-01-01  Unknown                  unknown
# 3  22820 1994-12-01 2000-01-01 2000-01-01  Unknown  business administration
# 4  24559 1994-11-10 2000-01-01 2000-01-01  Unknown                  unknown
#
#    Gender  Athlete    Height     Weight  ...   Math  Writing         State  \
# 0    Male        0  1.837690  37.246467  ...  60.02    81.44      In state
# 1    Male        0  1.794764  36.869630  ...  70.19    73.27       unknown
# 2    Male        0  1.795272  40.844637  ...  71.20    84.24      In state
# 3  Female        0  1.728007  40.807603  ...  55.89    73.16      In state
# 4  Female        1  1.712722  26.370427  ...  65.52    80.45  Out of state
#
#    LiveOnCampus      HowCommute  CommuteTime SleepTime StudyTime   Score  \
# 0     On Campus  Public Transit         27.0       7.0       1.0  311.20
# 1     On Campus  Public Transit         27.0       5.0       2.0  318.16
# 2       unknown  Public Transit         27.0       8.0       7.0  339.05
# 3     On Campus  Public Transit         27.0       2.0       6.0  291.79
# 4     On Campus  Public Transit         27.0       7.0       3.0  305.88
#
#         BMI
# 0  0.034584
# 1  0.035891
# 2  0.039738
# 3  0.042854
# 4  0.028189
#
# [5 rows x 24 columns]

# %%
#saving dataset. to_csv()
data.to_csv('cleanedDataset.csv')
