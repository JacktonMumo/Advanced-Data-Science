# %%
import pandas as pd
data = pd.read_csv('cleanedDataset.csv')
data.head(5)
# Out:
#    Unnamed: 0    ids        bday  enrolldate  expgradate     Rank  \
# 0           0  43783  1995-03-22  2000-01-01  2000-01-01  Unknown
# 1           1  20278  1995-01-01  2000-01-01  2000-01-01  Unknown
# 2           2  20389  1994-12-31  2000-01-01  2000-01-01  Unknown
# 3           3  22820  1994-12-01  2000-01-01  2000-01-01  Unknown
# 4           4  24559  1994-11-10  2000-01-01  2000-01-01  Unknown
#
#                      Major  Gender  Athlete     Height  ...  English Reading  \
# 0                  unknown    Male        0  72.350000  ...    88.24   81.50
# 1               Philosophy    Male        0  70.660000  ...    89.45   85.25
# 2                  unknown    Male        0  70.680000  ...    96.73   86.88
# 3  business administration  Female        0  68.031765  ...    74.06   88.68
# 4                  unknown  Female        1  67.430000  ...    82.61   77.30
#
#     Math  Writing         State  LiveOnCampus      HowCommute CommuteTime  \
# ...

# %%
# 1. What is the Average Study Time
mean_study = data['StudyTime'].mean()
mean_study
# Out:
# 7.208651399491094

# %%
# 2. What is the Average for Writing
mean_writing = data['Writing'].mean()
mean_writing
# Out:
# 79.52168316831684

# %%
# 3. What is the Max marks for Maths
max_math = data['Math'].max()
max_math
# Out:
# 93.78

# %%
# 4. What is the minimum height
min_height = data['Height'].min()
min_height
# Out:
# 55.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# 5. Create a Countplot of LiveOnCampus
plt.style.use('ggplot')

sns.countplot(data['LiveOnCampus'],palette='Reds')
plt.xlabel('Number of Students')
plt.ylabel('Live On Campus')
# Out:
# /tmp/ipykernel_4794/3799540893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['LiveOnCampus'],palette='Reds')
# Text(0, 0.5, 'Live On Campus')

# %%
# 6. Create a Count plot of Rank
sns.countplot(data['Rank'],palette='Oranges')
plt.xlabel('Number of Students')
# Out:
# /tmp/ipykernel_4794/661739109.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data['Rank'],palette='Oranges')
# Text(0.5, 0, 'Number of Students')

# %%
average = data.groupby(['LiveOnCampus','HowCommute'])['SleepTime'].mean()
average
# Out:
# LiveOnCampus  HowCommute
# Off Campus    Bike              5.364103
#               Car               5.120761
#               Public Transit    5.636752
#               Walk              4.818462
# On Campus     Public Transit    5.938914
# unknown       Car               6.560440
#               Public Transit    4.875740
#               Walk              2.000000
# Name: SleepTime, dtype: float64

# %%
# 7. Is there a difference in average sleep time between students who live on campus and those who commute?
import numpy
sns.barplot(x='LiveOnCampus', y='SleepTime',data=data,palette='Reds',estimator=numpy.mean)
sns.barplot(x='HowCommute', y='SleepTime',data=data,palette='Reds',estimator=numpy.mean)
# Out:
# /tmp/ipykernel_4794/3203967543.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='LiveOnCampus', y='SleepTime',data=data,palette='Reds',estimator=numpy.mean)
# /tmp/ipykernel_4794/3203967543.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='HowCommute', y='SleepTime',data=data,palette='Reds',estimator=numpy.mean)
# <Axes: xlabel='LiveOnCampus', ylabel='SleepTime'>

# %%
# 8. What proportion of students are ranked?(use bargraph for this)
sns.barplot(data['Rank'],palette='Oranges')
plt.title('Distribution of Ranks')
plt.xlabel('Number of Students')
plt.ylabel('Ranks')
# Out:
# /tmp/ipykernel_4794/2057720748.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data['Rank'],palette='Oranges')
# Text(0, 0.5, 'Ranks')

# %%
# 9. Create a Swarm Plot of Athlete and Writing, Include Gender (hue)
sns.swarmplot(x='Athlete',y='Writing',hue='Gender',palette='magma',data=data)
# Out:
# <Axes: xlabel='Athlete', ylabel='Writing'>

# %%
# 10. How many students smoke?
ax = sns.countplot(x=data['Smoking'],palette='Reds')
plt.xlabel('Smoking')
plt.ylabel('Number of Students')
for p in ax.patches:
    txt = str(p.get_height().round(1)) + ''
    txt_x = p.get_x()
    txt_y = p.get_height()
    ax.text(txt_x,txt_y,txt)
# Out:
# /tmp/ipykernel_4794/2643783827.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=data['Smoking'],palette='Reds')

# %%
# 11. What are the 25th, 50th, and 75th percentiles of the number of students in the dataset?
data.describe()
# Out:
#        Unnamed: 0           ids     Athlete      Height      Weight  \
# count  435.000000    435.000000  435.000000  435.000000  435.000000
# mean   217.000000  35279.022989    0.422989   68.031765  181.031569
# std    125.717938   8637.733605    0.494602    5.157336   39.737784
# min      0.000000  20183.000000    0.000000   55.000000  101.710000
# 25%    108.500000  28001.000000    0.000000   65.025000  156.700000
# 50%    217.000000  35350.000000    0.000000   67.990000  181.031569
# 75%    325.500000  42655.500000    1.000000   71.245000  197.365000
# max    434.000000  49947.000000    1.000000   84.410000  350.070000
#
#            Sprint     English     Reading        Math     Writing  \
# count  435.000000  435.000000  435.000000  435.000000  435.000000
# mean     6.581933   82.787555   82.070800   65.468009   79.521683
# std      1.137571    6.631760    7.572994    8.249530    5.310927
# min      4.503000   59.830000   55.110000   35.320000   64.060000
# ...

# %%
# 12. What is the distribution of commute times? Are there any outliers?(use histogram)
sns.histplot(data['CommuteTime'],palette='Oranges')
plt.title('Distribution of commute time')
plt.xlabel('Commute Time')
plt.ylabel('Number of Students')
# Out:
# /tmp/ipykernel_4794/4013557143.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data['CommuteTime'],palette='Oranges')
# Text(0, 0.5, 'Number of Students')

# %%
# 13. Is there a significant difference in average height between male and female students?
average = data.groupby('Gender')[['Height']].mean()
average
# Out:
#             Height
# Gender
# Female   65.835951
# Male     70.502875
# Neutral  66.183333

# %%
# 14. How do average exam scores (English, Reading, Math, Writing) vary across different states?
average = data.groupby('State')[['English', 'Reading', 'Math', 'Writing']].mean()
average
# Out:
#                 English    Reading       Math    Writing
# State
# In state      82.800815  82.089890  65.538949  79.383924
# Out of state  82.268009  82.164387  64.753766  79.574646
# unknown       84.442132  81.522963  67.129630  80.939384

# %%
# 15. What is the average height and weight of the students?
mean_height = data['Height'].mean()
print(f'The mean height is {mean_height}')
mean_weight = data['Weight'].mean()
print(f'The mean weight is {mean_weight}')
# Out:
# The mean height is 68.03176470588235
# The mean weight is 181.03156914893617
